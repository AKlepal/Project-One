# %% [markdown]
# # Data Throne

# %% [markdown]
# #

# %% [markdown]
# ### Introduction
#
# * For this project we have decided to take a small tour into the world of Game of Thrones. However, this tour is not one filled with joy and happiness as we dive into a subject that mortals all fear, Death. This project is a collection of data we have analyized to find the causes of death to the characters. Some of what we have explored revlves around how they died, where they died, their allegiance, and so forth. Remember death is imminent, but have no fear for today we find ourselves in Westeros.
#
# Our team had found some of the finest data on the people of Westeros both living and dead, to try to piece togther why this land has so much death in it, and what are the challenges the common people face from all the acts of war.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# %%
GOT_deathdata_path = "Resources/GOT_data_set.csv"

# %%
GOT_df = pd.read_csv(GOT_deathdata_path)
GOT_df.head()
# Out:
#    order  season  episode character_killed        killer          method  \
# 0      1       1        1     Waymar Royce  White Walker       Ice sword
# 1      2       1        1            Gared  White Walker       Ice sword
# 2      3       1        1             Will     Ned Stark     Sword (Ice)
# 3      4       1        1             Stag      Direwolf  Direwolf teeth
# 4      5       1        1         Direwolf          Stag          Antler
#
#   method_cat                       reason         location  \
# 0      Blade                      Unknown  Beyond the Wall
# 1      Blade                      Unknown  Beyond the Wall
# 2      Blade  Deserting the Night’s Watch       Winterfell
# 3     Animal                      Unknown       Winterfell
# 4     Animal                      Unknown       Winterfell
#
#                    allegiance  importance
# 0  House Royce, Night’s Watch         2.0
# 1               Night’s Watch         2.0
# ...

# %%
GOT_df.rename(columns={"order": "Order", "season": "Season", "episode":"Episode", "character_killed":"Character Killed", "killer":"Killer", 
                       "method":"Method", "method_cat":"Method Category", "reason":"Reason", "location":"Location", 
                       "allegiance":"Allegiance", "importance":"Importance"}, inplace=True)

GOT_df
# Out:
#       Order  Season  Episode    Character Killed        Killer  \
# 0         1       1        1        Waymar Royce  White Walker
# 1         2       1        1               Gared  White Walker
# 2         3       1        1                Will     Ned Stark
# 3         4       1        1                Stag      Direwolf
# 4         5       1        1            Direwolf          Stag
# ...     ...     ...      ...                 ...           ...
# 6882   6883       8        5     Nora’s daughter        Drogon
# 6883   6884       8        5     Jaime Lannister        Drogon
# 6884   6885       8        5    Cersei Lannister        Drogon
# 6885   6886       8        6   Lannister soldier     Grey Worm
# 6886   6887       8        6  Daenerys Targaryen      Jon Snow
#
#               Method Method Category  \
# 0          Ice sword           Blade
# 1          Ice sword           Blade
# 2        Sword (Ice)           Blade
# 3     Direwolf teeth          Animal
# ...

# %%
GOT_df.drop(columns={"Season","Episode"})
# Out:
#       Order    Character Killed        Killer          Method Method Category  \
# 0         1        Waymar Royce  White Walker       Ice sword           Blade
# 1         2               Gared  White Walker       Ice sword           Blade
# 2         3                Will     Ned Stark     Sword (Ice)           Blade
# 3         4                Stag      Direwolf  Direwolf teeth          Animal
# 4         5            Direwolf          Stag          Antler          Animal
# ...     ...                 ...           ...             ...             ...
# 6882   6883     Nora’s daughter        Drogon      Dragonfire          Animal
# 6883   6884     Jaime Lannister        Drogon          Rubble        Crushing
# 6884   6885    Cersei Lannister        Drogon          Rubble        Crushing
# 6885   6886   Lannister soldier     Grey Worm           Knife           Blade
# 6886   6887  Daenerys Targaryen      Jon Snow           Knife           Blade
#
# ...
